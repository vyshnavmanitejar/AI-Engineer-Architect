# %% [markdown]
# Feature Engineering
# - Creating new features or transforming existing
# ones to expose useful patterns that ML models can
# learn from.

# %% [markdown]
# Why do we need it?
# - Because ML models don't know domain logic — we
# have to give them the right signals.

# %% [markdown]
# Common Feature Engineering Techniques in ML:
# - Mathematical Combinations
# - Target-Based Flags
# - Binning (when it helps)
# - Time-Based Features (if time exists)
